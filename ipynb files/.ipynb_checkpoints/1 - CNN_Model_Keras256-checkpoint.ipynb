# %% [markdown]
# # **Method 1 - Traffic Sign Classification using Keras**
# **Neural Networks - Final project <br>**
# **Submitted by:** Team Rocket (Ajay, Akshita, Jonatas, Angelica, Kuldeep) <br>
# **Instructor:** Mohammad Islam

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from keras.utils.np_utils import to_categorical
from tensorflow.keras.constraints import unit_norm
from tensorflow.python.keras import regularizers

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

import os
import cv2
import random
import time
import pickle

SEED = 0

def set_seeds(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
  
def set_global_determinism(seed=SEED):
    set_seeds(seed=seed)

    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)

# Call the above function with seed value
set_global_determinism(seed=SEED)

# %%
# load Dataset

X = pickle.load(open("/content/gdrive/MyDrive/NN_assignment_2/datasets/X_256.pickle", "rb"))
y = pickle.load(open("/content/gdrive/MyDrive/NN_assignment_2/datasets/y_256.pickle", "rb"))
categories = pickle.load(open("/content/gdrive/MyDrive/NN_assignment_2/datasets/categories.pickle", "rb"))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
num_classes = len(categories)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (30100, 256, 256, 1)
# (30100, 43)
# (12900, 256, 256, 1)
# (12900, 43)

# %%
def print_graphs(model_history):
     # summarize history for loss
    plt.plot(model_history.history['loss'], color='orange')
    plt.plot(model_history.history['val_loss'], color='blue')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Training loss', 'Validation loss'], loc='upper left')
    plt.show()
    
    # summarize history for accuracy
    plt.plot(model_history.history['accuracy'], color='orange')
    plt.plot(model_history.history['val_accuracy'], color='blue')
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper left')
    plt.show()

# %% [markdown]
# ## **1.2. MODEL 1**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', activation='relu'))
cnn.add(MaxPooling2D())

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu'))
cnn.add(MaxPooling2D())

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              268436480
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 268,532,651
# Trainable params: 268,532,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 941/941 [==============================] - 102s 91ms/step - loss: 1.4456 - accuracy: 0.6504 - val_loss: 0.6249 - val_accuracy: 0.8453
# Epoch 2/10
# 941/941 [==============================] - 85s 90ms/step - loss: 0.4251 - accuracy: 0.8869 - val_loss: 0.5354 - val_accuracy: 0.8657
# Epoch 3/10
# 941/941 [==============================] - 85s 90ms/step - loss: 0.2310 - accuracy: 0.9344 - val_loss: 0.5825 - val_accuracy: 0.8681
# Epoch 4/10
# 941/941 [==============================] - 85s 90ms/step - loss: 0.1623 - accuracy: 0.9540 - val_loss: 0.6644 - val_accuracy: 0.8691
# Epoch 5/10
# 941/941 [==============================] - 84s 89ms/step - loss: 0.1104 - accuracy: 0.9680 - val_loss: 0.7313 - val_accuracy: 0.8803
# Epoch 6/10
# 941/941 [==============================] - 85s 90ms/step - loss: 0.1011 - accuracy: 0.9724 - val_loss: 0.6561 - val_accuracy: 0.8846
# Epoch 7/10
# 941/941 [==============================] - 85s 90ms/step - loss: 0.0841 - accuracy: 0.9775 - val_loss: 0.6598 - val_accuracy: 0.8934
# Epoch 8/10
# 941/941 [==============================] - 85s 90ms/step - loss: 0.0702 - accuracy: 0.9808 - val_loss: 0.7392 - val_accuracy: 0.8914
# Epoch 9/10
# 941/941 [==============================] - 85s 90ms/step - loss: 0.0594 - accuracy: 0.9849 - val_loss: 0.7892 - val_accuracy: 0.8864
# Epoch 10/10
# 941/941 [==============================] - 84s 90ms/step - loss: 0.0529 - accuracy: 0.9868 - val_loss: 0.7858 - val_accuracy: 0.8890
# Time elapsed: 864.6949391365051s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.3. MODEL 2**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 268,532,651
# Trainable params: 268,532,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 941/941 [==============================] - 89s 94ms/step - loss: 3.1842 - accuracy: 0.1963 - val_loss: 1.2346 - val_accuracy: 0.6976
# Epoch 2/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.9291 - accuracy: 0.7684 - val_loss: 0.7098 - val_accuracy: 0.8260
# Epoch 3/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.5423 - accuracy: 0.8558 - val_loss: 0.5886 - val_accuracy: 0.8522
# Epoch 4/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.3723 - accuracy: 0.8934 - val_loss: 0.5607 - val_accuracy: 0.8651
# Epoch 5/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.2663 - accuracy: 0.9221 - val_loss: 0.5895 - val_accuracy: 0.8602
# Epoch 6/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.2050 - accuracy: 0.9389 - val_loss: 0.5527 - val_accuracy: 0.8688
# Epoch 7/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.1579 - accuracy: 0.9527 - val_loss: 0.5971 - val_accuracy: 0.8716
# Epoch 8/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.1335 - accuracy: 0.9597 - val_loss: 0.6300 - val_accuracy: 0.8739
# Epoch 9/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.1051 - accuracy: 0.9673 - val_loss: 0.7002 - val_accuracy: 0.8598
# Epoch 10/10
# 941/941 [==============================] - 88s 93ms/step - loss: 0.1155 - accuracy: 0.9647 - val_loss: 0.7891 - val_accuracy: 0.8686
# Time elapsed: 878.6416478157043s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## 1.3. MODEL 2.2

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=20, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 268,532,651
# Trainable params: 268,532,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 941/941 [==============================] - 88s 93ms/step - loss: 3.8655 - accuracy: 0.0224 - val_loss: 3.7618 - val_accuracy: 0.0218
# Epoch 2/20
# 941/941 [==============================] - 87s 93ms/step - loss: 3.5188 - accuracy: 0.0933 - val_loss: 1.7618 - val_accuracy: 0.5778
# Epoch 3/20
# 941/941 [==============================] - 87s 93ms/step - loss: 1.1011 - accuracy: 0.7309 - val_loss: 0.7641 - val_accuracy: 0.8159
# Epoch 4/20
# 941/941 [==============================] - 88s 93ms/step - loss: 0.6349 - accuracy: 0.8341 - val_loss: 0.6303 - val_accuracy: 0.8432
# Epoch 5/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.4575 - accuracy: 0.8758 - val_loss: 0.5861 - val_accuracy: 0.8609
# Epoch 6/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.3248 - accuracy: 0.9068 - val_loss: 0.6032 - val_accuracy: 0.8688
# Epoch 7/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.2680 - accuracy: 0.9221 - val_loss: 0.5729 - val_accuracy: 0.8696
# Epoch 8/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.2027 - accuracy: 0.9379 - val_loss: 0.6305 - val_accuracy: 0.8646
# Epoch 9/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.1772 - accuracy: 0.9476 - val_loss: 0.6204 - val_accuracy: 0.8747
# Epoch 10/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.1476 - accuracy: 0.9554 - val_loss: 0.6396 - val_accuracy: 0.8700
# Epoch 11/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.1197 - accuracy: 0.9642 - val_loss: 0.6852 - val_accuracy: 0.8745
# Epoch 12/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.1124 - accuracy: 0.9667 - val_loss: 0.6311 - val_accuracy: 0.8740
# Epoch 13/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.1073 - accuracy: 0.9677 - val_loss: 0.6413 - val_accuracy: 0.8757
# Epoch 14/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.0978 - accuracy: 0.9703 - val_loss: 0.6383 - val_accuracy: 0.8798
# Epoch 15/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.0733 - accuracy: 0.9780 - val_loss: 0.7218 - val_accuracy: 0.8694
# Epoch 16/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.0698 - accuracy: 0.9795 - val_loss: 0.6946 - val_accuracy: 0.8791
# Epoch 17/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.0699 - accuracy: 0.9792 - val_loss: 0.7022 - val_accuracy: 0.8794
# Epoch 18/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.0754 - accuracy: 0.9787 - val_loss: 0.7250 - val_accuracy: 0.8843
# Epoch 19/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.0603 - accuracy: 0.9828 - val_loss: 0.7522 - val_accuracy: 0.8834
# Epoch 20/20
# 941/941 [==============================] - 87s 93ms/step - loss: 0.0703 - accuracy: 0.9808 - val_loss: 0.8947 - val_accuracy: 0.8651
# Time elapsed: 1746.81058883667s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.4. MODEL 3**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=30, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 268,532,651
# Trainable params: 268,532,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
#
# 941/941 [==============================] - 86s 92ms/step - loss: 0.0415 - accuracy: 0.9911 - val_loss: 0.5827 - val_accuracy: 0.8975
# Epoch 23/30
# 941/941 [==============================] - 87s 92ms/step - loss: 0.0346 - accuracy: 0.9936 - val_loss: 0.6150 - val_accuracy: 0.9029
# Epoch 24/30
# 941/941 [==============================] - 87s 92ms/step - loss: 0.0378 - accuracy: 0.9921 - val_loss: 0.5626 - val_accuracy: 0.9021
# Epoch 25/30
# 941/941 [==============================] - 87s 92ms/step - loss: 0.0350 - accuracy: 0.9935 - val_loss: 0.6869 - val_accuracy: 0.8975
# Epoch 26/30
# 941/941 [==============================] - 87s 92ms/step - loss: 0.0410 - accuracy: 0.9919 - val_loss: 0.6419 - val_accuracy: 0.8964
# Epoch 27/30
# 941/941 [==============================] - 87s 92ms/step - loss: 0.0349 - accuracy: 0.9927 - val_loss: 0.6500 - val_accuracy: 0.8949
# Epoch 28/30
# 941/941 [==============================] - 87s 92ms/step - loss: 0.0343 - accuracy: 0.9931 - val_loss: 0.6120 - val_accuracy: 0.8991
# Epoch 29/30
# 941/941 [==============================] - 87s 92ms/step - loss: 0.0322 - accuracy: 0.9941 - val_loss: 0.6710 - val_accuracy: 0.8998
# Epoch 30/30
# 941/941 [==============================] - 87s 92ms/step - loss: 0.0341 - accuracy: 0.9932 - val_loss: 0.6475 - val_accuracy: 0.9040
# Time elapsed: 2598.323898077011s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.5. MODEL 4**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())


start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=30, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 268,532,651
# Trainable params: 268,532,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 941/941 [==============================] - 87s 91ms/step - loss: 4.6852 - accuracy: 0.0248 - val_loss: 3.9157 - val_accuracy: 0.0259
# Epoch 2/30
# 941/941 [==============================] - 86s 91ms/step - loss: 2.4223 - accuracy: 0.4258 - val_loss: 1.0588 - val_accuracy: 0.7747
# Epoch 3/30
# 941/941 [==============================] - 86s 91ms/step - loss: 0.8431 - accuracy: 0.8115 - val_loss: 0.7085 - val_accuracy: 0.8455
# Epoch 4/30
# 941/941 [==============================] - 85s 91ms/step - loss: 0.4919 - accuracy: 0.8855 - val_loss: 0.5943 - val_accuracy: 0.8673
# Epoch 5/30
# Epoch 25/30
# 941/941 [==============================] - 85s 91ms/step - loss: 0.0334 - accuracy: 0.9935 - val_loss: 0.6580 - val_accuracy: 0.8932
# Epoch 26/30
# 941/941 [==============================] - 85s 91ms/step - loss: 0.0408 - accuracy: 0.9915 - val_loss: 0.6094 - val_accuracy: 0.8978
# Epoch 27/30
# 941/941 [==============================] - 85s 91ms/step - loss: 0.0336 - accuracy: 0.9928 - val_loss: 0.6645 - val_accuracy: 0.8989
# Epoch 28/30
# 941/941 [==============================] - 85s 91ms/step - loss: 0.0336 - accuracy: 0.9940 - val_loss: 0.6672 - val_accuracy: 0.8833
# Epoch 29/30
# 941/941 [==============================] - 85s 91ms/step - loss: 0.0329 - accuracy: 0.9930 - val_loss: 0.6181 - val_accuracy: 0.8941
# Epoch 30/30
# 941/941 [==============================] - 85s 90ms/step - loss: 0.0314 - accuracy: 0.9940 - val_loss: 0.6278 - val_accuracy: 0.9005
# Time elapsed: 2560.552053451538s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.6. MODEL 5**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_5 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 268,532,651
# Trainable params: 268,532,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 941/941 [==============================] - 87s 91ms/step - loss: 5.2061 - accuracy: 0.0229 - val_loss: 3.9523 - val_accuracy: 0.0336
# Epoch 2/10
# 941/941 [==============================] - 86s 91ms/step - loss: 2.6949 - accuracy: 0.3584 - val_loss: 1.0414 - val_accuracy: 0.7791
# Epoch 3/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.8955 - accuracy: 0.8031 - val_loss: 0.7939 - val_accuracy: 0.8290
# Epoch 4/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.6615 - accuracy: 0.8560 - val_loss: 0.7871 - val_accuracy: 0.8271
# Epoch 5/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.4548 - accuracy: 0.8962 - val_loss: 0.6228 - val_accuracy: 0.8643
# Epoch 6/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.3182 - accuracy: 0.9252 - val_loss: 0.7638 - val_accuracy: 0.8193
# Epoch 7/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.2587 - accuracy: 0.9387 - val_loss: 0.6182 - val_accuracy: 0.8729
# Epoch 8/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.2119 - accuracy: 0.9466 - val_loss: 0.6209 - val_accuracy: 0.8780
# Epoch 9/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.1677 - accuracy: 0.9575 - val_loss: 0.6422 - val_accuracy: 0.8735
# Epoch 10/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.1513 - accuracy: 0.9612 - val_loss: 0.6432 - val_accuracy: 0.8777
# Time elapsed: 858.2704293727875s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.7. MODEL 6**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.05))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.5))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(len(categories), activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_7 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 268,532,651
# Trainable params: 268,532,651
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 941/941 [==============================] - 87s 92ms/step - loss: 4.2265 - accuracy: 0.0217 - val_loss: 3.8639 - val_accuracy: 0.0233
# Epoch 2/10
# 941/941 [==============================] - 86s 91ms/step - loss: 3.8468 - accuracy: 0.0247 - val_loss: 3.8084 - val_accuracy: 0.0329
# Epoch 3/10
# 941/941 [==============================] - 86s 91ms/step - loss: 3.0133 - accuracy: 0.2483 - val_loss: 1.1554 - val_accuracy: 0.7342
# Epoch 4/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.9817 - accuracy: 0.7627 - val_loss: 0.7475 - val_accuracy: 0.8259
# Epoch 5/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.6285 - accuracy: 0.8410 - val_loss: 0.6400 - val_accuracy: 0.8504
# Epoch 6/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.4551 - accuracy: 0.8817 - val_loss: 0.6218 - val_accuracy: 0.8514
# Epoch 7/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.3458 - accuracy: 0.9079 - val_loss: 0.5844 - val_accuracy: 0.8642
# Epoch 8/10
# 941/941 [==============================] - 86s 91ms/step - loss: 0.2855 - accuracy: 0.9231 - val_loss: 0.5763 - val_accuracy: 0.8726
# Epoch 9/10
# 941/941 [==============================] - 85s 91ms/step - loss: 0.2251 - accuracy: 0.9396 - val_loss: 0.5993 - val_accuracy: 0.8754
# Epoch 10/10
# 941/941 [==============================] - 85s 91ms/step - loss: 0.1983 - accuracy: 0.9452 - val_loss: 0.6191 - val_accuracy: 0.8692
# Time elapsed: 862.5689420700073s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.8. MODEL 7**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(3,3), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(len(categories), activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=30, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 256, 256, 32)      320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                44075
# =================================================================
# Total params: 268,499,371
# Trainable params: 268,499,371
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/30
# 941/941 [==============================] - 82s 86ms/step - loss: 4.7714 - accuracy: 0.2825 - val_loss: 1.7675 - val_accuracy: 0.6005
# Epoch 2/30
# 941/941 [==============================] - 78s 83ms/step - loss: 1.2485 - accuracy: 0.7252 - val_loss: 1.1632 - val_accuracy: 0.7450
# Epoch 3/30
# 941/941 [==============================] - 79s 84ms/step - loss: 0.8437 - accuracy: 0.8150 - val_loss: 0.9187 - val_accuracy: 0.8021
# Epoch 4/30
# 941/941 [==============================] - 78s 83ms/step - loss: 0.6186 - accuracy: 0.8588 - val_loss: 0.9841 - val_accuracy: 0.7726
# Epoch 5/30
# 941/941 [==============================] - 78s 83ms/step - loss: 0.4619 - accuracy: 0.8950 - val_loss: 0.8534 - val_accuracy: 0.8094
# Epoch 6/30
# 941/941 [==============================] - 78s 83ms/step - loss: 0.3498 - accuracy: 0.9181 - val_loss: 0.8290 - val_accuracy: 0.8095
# Epoch 7/30
# 941/941 [==============================] - 78s 83ms/step - loss: 0.2747 - accuracy: 0.9368 - val_loss: 0.8151 - val_accuracy: 0.8110
# Epoch 8/30
# 941/941 [==============================] - 79s 83ms/step - loss: 0.2119 - accuracy: 0.9519 - val_loss: 0.7321 - val_accuracy: 0.8405
# Epoch 9/30
# 941/941 [==============================] - 79s 83ms/step - loss: 0.1823 - accuracy: 0.9588 - val_loss: 0.7306 - val_accuracy: 0.8399
# Epoch 10/30
# 941/941 [==============================] - 79s 83ms/step - loss: 0.1470 - accuracy: 0.9683 - val_loss: 0.6999 - val_accuracy: 0.8467
# Epoch 11/30
# 941/941 [==============================] - 79s 84ms/step - loss: 0.1233 - accuracy: 0.9751 - val_loss: 0.7268 - val_accuracy: 0.8420
# Epoch 12/30
# 941/941 [==============================] - 79s 84ms/step - loss: 0.1187 - accuracy: 0.9760 - val_loss: 0.6709 - val_accuracy: 0.8616
